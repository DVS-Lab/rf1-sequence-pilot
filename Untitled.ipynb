# %%
import getpass
import os
import subprocess
import glob
import sys

try:
    import xnat
except ImportError:
    raise ImportError(
        """
        Module for XNAT not found- Run the following command:
        \n\n python3 -m pip install xnat"""
    )
os.umask(0)
#url = sys.argv[1]
#session = sys.argv[2]
#outputDir = sys.argv[3]
#subject = sys.argv[4]

url = "https://xnat.cla.temple.edu"
session = "Smith-RF1pilot"
outputDir = "/data/sourcedata/rf1-sequence-pilot"

subs=os.listdir(outputDir)

def download_sub(url, session, outputDir):
    user = input("Enter Your XNAT Username\n\n>> ")
    password = getpass.getpass("Enter Your XNAT Password\n\n>> ")
    with xnat.connect(url, user, password) as connect:
        for sub in connect.projects[session].subjects.values():
            if sub.label in subs:
                print("%s already retrieved from XNAT"%(sub.label))
            else:
                print("Downloading .. %s"%(sub.label))
                sub.download_dir(outputDir)
    return

download_sub(url, session, outputDir)
# Out:
# Enter Your XNAT Username
#
# >> tuj71575
# Enter Your XNAT Password
#
# >> ········
# [CRITICAL] Login attempt failed for https://xnat.cla.temple.edu, please make sure your credentials for user tuj71575 are correct!
# ---------------------------------------------------------------------------
# XNATLoginFailedError                      Traceback (most recent call last)
# <ipython-input-6-5ee18f79d44d> in <module>
#      37     return
#      38
# ---> 39 download_sub(url, session, outputDir)
#
# <ipython-input-6-5ee18f79d44d> in download_sub(url, session, outputDir)
#      28     user = input("Enter Your XNAT Username\n\n>> ")
#      29     password = getpass.getpass("Enter Your XNAT Password\n\n>> ")
# ---> 30     with xnat.connect(url, user, password) as connect:
#      31         for sub in connect.projects[session].subjects.values():
#      32             if sub.label in subs:
#
# ~/anaconda3/lib/python3.7/site-packages/xnat/__init__.py in connect(server, user, password, verify, netrc_file, debug, extension_types, loglevel, logger, detect_redirect, no_parse_model, default_timeout)
#     400
#     401     # Check if login is successful
# --> 402     logged_in_user = check_auth(requests_session, server=server, user=user, logger=logger)
#     403
#     404     # Create the XNAT connection
#
# ~/anaconda3/lib/python3.7/site-packages/xnat/__init__.py in check_auth(requests_session, server, user, logger)
#      64         message = 'Login attempt failed for {}, please make sure your credentials for user {} are correct!'.format(server, user)
#      65         logger.critical(message)
# ---> 66         raise exceptions.XNATLoginFailedError(message)
#      67
#      68     if test_auth_request.status_code != 200:
#
# XNATLoginFailedError: Login attempt failed for https://xnat.cla.temple.edu, please make sure your credentials for user tuj71575 are correct!

# %%
os.mkdir('/data/sourcedata/rf1-sequence-pilot')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ea774d7403f8> in <module>
# ----> 1 os.mkdir('/data/sourcedata/rf1-sequence-pilot')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/sourcedata/rf1-sequence-pilot'

# %%
"tuj71575"
"secure_Spring22"
