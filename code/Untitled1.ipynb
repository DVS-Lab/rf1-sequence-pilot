# %%
import pandas as pd
import os

# %%
os.listdir("../derivatives/mriqc/")
# Out:
# ['sub-10008',
#  'group_T1w.html',
#  '.bidsignore',
#  'group_bold.tsv',
#  'group_T1w.tsv',
#  'group_bold.html',
#  'sub-10007',
#  'logs',
#  'dataset_description.json']
